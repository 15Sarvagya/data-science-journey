# %% [markdown]
# DAY 06 (Practice)

# %%
import pandas as pd

# %%
#DataFrame
pd.DataFrame({'DAD':["Rishi","Kesh","singh"],'Mother':["Anamika","Kumari ","Singh"]})
# Out:
#      DAD   Mother
# 0  Rishi  Anamika
# 1   Kesh  Kumari
# 2  singh    Singh

# %%
pd.DataFrame({'DAD':["Rishi","Kesh","Singh"],'Mother':["Anamika","  ","Singh"]},index = ["First Name","Middle Name","Last Name"])
# Out:
#                DAD   Mother
# First Name   Rishi  Anamika
# Middle Name   Kesh
# Last Name    Singh    Singh

# %%
pd.DataFrame({'Maths':[89,91],'Physics':[90,78]},index=["Sarvagya","Vasu"])
# Out:
#              Maths  Physics
#    Sarvagya     89       90
# Vasu            91       78

# %%
pd.DataFrame({'Maths':[89,91],'Physics':[90,78]},index=[1,2])
# Out:
#    Maths  Physics
# 1     89       90
# 2     91       78

# %%
#Series
pd.Series([6,8,4,9,4])
# Out:
# 0    6
# 1    8
# 2    4
# 3    9
# 4    4
# dtype: int64

# %%
pd.Series([6,8,4,9,4],index =['1','2','3','4','5'])
# Out:
# 1    6
# 2    8
# 3    4
# 4    9
# 5    4
# dtype: int64

# %%
pd.Series([6,8,4,9,4],[7,5,4,9,2])
# Out:
# 7    6
# 5    8
# 4    4
# 9    9
# 2    4
# dtype: int64

# %%
pd.Series([6,8,4,9,4],[7,5,4,9,2]),index =['1','2','3','4','5'])
# Out:
#   Cell In[34], line 1
#     pd.Series([6,8,4,9,4],[7,5,4,9,2]),index =['1','2','3','4','5'])
#                                                                    ^
# SyntaxError: unmatched ')'

# %%
import pandas as pd
fruits = pd.DataFrame({"Apples":[30],"Bananas":[21]})

# Check your answer

print(fruits)
# Out:
#    Apples  Bananas
# 0      30       21
