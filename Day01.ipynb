# %%
print("Sarvagya Singh")
# Out:
# Sarvagya Singh

# %%
print(2+3)
# Out:
# 5

# %%
2+32+3
# Out:
# 37

# %%
a,b=10,65.654
print(type(b))
# Out:
# <class 'float'>

# %%
x=3
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      10
# b          float    65.654
# x          int      3

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      10
# b          float    65.654
# x          int      3

# %%
I = 5
print(I)
# Out:
# 5

# %%
# del a
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# b          float    65.654
# x          int      3

# %%
s1="hello"
s2="ram"
print(s1+" " + s2)
# Out:
# hello ram

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# b          float    65.654
# s1         str      hello
# s2         str      ram
# x          int      3

# %%
a = 10
sumofaAndb = (a+b)
print(sumofaAndb)
# Out:
# 75.654

# %%
# %whos
# Out:
# Variable     Type     Data/Info
# -------------------------------
# a            int      10
# b            float    65.654
# s1           str      hello
# s2           str      ram
# sumofaAndb   float    75.654
# x            int      3

# %%
type(sumofaAndb)
# Out:
# float

# %%
sumofaAndb = (a+b)
print(sumofaAndb)
# Out:
# 75.654

# %%
v=((sumofaAndb)**4/4)
print(v)
# Out:
# 8189692.378955043

# %%
v=((sumofaAndb)**4/4)
print(v)
# Out:
# 8189692.378955043

# %%
10/3
# Out:
# 3.3333333333333335

# %%
_
# Out:
# 3.3333333333333335

# %%
x3= 56
print(x3)
# Out:
# 56

# %%
t_=4
print(t_)
# Out:
# 4

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
print(not(True))
print(not(False))
# Out:
# False
# True

# %%
a= True
b=False
c=True
# %whos
# Out:
# Variable     Type     Data/Info
# -------------------------------
# a            bool     True
# b            bool     False
# c            bool     True
# s1           str      hello
# s2           str      ram
# sumofaAndb   float    75.654
# t_           int      4
# v            float    8189692.378955043
# x            int      3
# x3           int      56

# %%
print(2<3)
# Out:
# True

# %%
3==4
# Out:
# False

# %%
3==3.7
# Out:
# False

# %%
x =3
y =4
z=6.3
w=-9
(x<y) and  (w==x)or(z>y)
# Out:
# True

# %%
True or False and True
# Out:
# True

# %%
print(round(4.6))
print(round(4.50000001))
print(round(4.2))
print(round(4.54221,3))
# Out:
# 5
# 5
# 4
# 4.542

# %%
divmod(27,5)
# Out:
# (5, 2)

# %%
x =divmod(34,2)
print(x)
print(type(x))
# Out:
# (17, 0)
# <class 'tuple'>

# %%
x[0]
# Out:
# 17

# %%
x[1]
# Out:
# 0

# %%
print(isinstance("hi",str))
print(isinstance(1,int))
print(isinstance(1.0,(int,float)))
print(isinstance(2+3j,(int, float , str , complex)))
# Out:
# True
# True
# True
# True

# %%
print(pow(2,3))
print(pow(4,3,2))
# Out:
# 8
# 0

# %%
x = int(input("enter a number"))
# Out:
# enter a number 78

# %%
type(x)
# Out:
# int

# %%
print(x-34)
# Out:
# 44

# %% [markdown]
# #ControlFlow

# %%
a = int(input("enter value of a"))
b = int (input("enter value of b"))

if b>a:
    print(b)
else:
    print(a)
print("done")
# Out:
# enter value of a 5
# enter value of b 5
# 5
# done

# %%
a = int(input("enter value of a"))
b = int (input("enter value of b"))

if b>a:
    print(b)
if a>b:
    print(a)

print("done")
# Out:
# enter value of a 5
# enter value of b 5
# done

# %%
a = int(input("enter value of a"))
b = int (input("enter value of b"))

if b>a:
    print(b)
elif a==b:
    print("they are equal")
else:
    print(a)
print("done")
# Out:
# enter value of a 5
# enter value of b 5
# they are equal
# done

# %%
a = int(input())
b=int(input())
print("A") if a>b else print("=") if a==b else print("B")
# Out:
#  5
#  5
# =

# %%
a = int(input())
if a>=85:
    print("A+")
elif (a>=80) and (a<85):
    print("A")
elif (a>=70 )and (a<80):
    print("B+")
elif (a>=60) and (a<70_):
    print("B")
elif (a>=40) and (a<60):
    print("C")
else:
    print("Fail")
print("Grade Calculated")
# Out:
#  89
# A+
# Grade Calculated

# %%
a = int(input())
if a>10:
    print(">10")
elif not (a>10):
    print("<10")
# Out:
#  12
# >10

# %%
x= int(input())
if x>10:
    print("your number is greater than 10")
    if x>20:
        print("number is greater than 20")
    else:
        print("number is less than 20")
else:
    print("number is less than 10")
# Out:
#  11
# your number is greater than 10
# number is less than 20

# %%
x = float(input("enter a number"))
y= round(x)
if x>0:
    if y>x:
        initPortion =y-1
    else:
        initPortion = y
else:
    if y<x:
       initPortion = y+1
    else:
        initPortion = y
if initPortion %2  == 01
    print("even")
else:
    print("odd")

# %%
n = int(input("enter number of iterations"))
i=1
while(i<n):
    print(i)
    i+=1
print("done")
# Out:
# enter number of iterations 5
# 1
# 2
# 3
# 4
# done

# %%
n = int(input())
i =1
while i < n :
    print(i**2)
    i +=1
# Out:
#  5
# 1
# 4
# 9
# 16

# %%
n = int(input())
i =1
while i<n:
    if i%2 == 0:
        print(i)
    else:
        pass
    i +=1
print("done")
# Out:
#  5
# 2
# 4
# done
