# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
gas =pd.read_csv(r"C:\Users\sarva\Downloads\gas_prices.csv")
print(gas)
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.title("GAS PRICES",fontdict={'fontfamily': 'sans-serif','fontsize':20})
# plt.plot(gas.Year,gas.USA,'r.-',label='USA')
# plt.plot(gas.Year,gas.Australia,'b.-',label='Australia')
# plt.plot(gas.Year,gas.Canada,'.-',label='Canada')
# plt.plot(gas.Year,gas.Japan,'.-',label='Japan')
# plt.plot(gas.Year,gas['South Korea'],'.-',label='South Korea')


#Another way to plot many values
for country in gas:
    if country =='Year':
        continue
    plt.plot(gas.Year,gas[country],'.-',label = country)
    
plt.xticks(gas.Year[::3])
plt.xlabel("Years")
plt.ylabel("Prices in USD")
plt.legend()
plt.show()

# %%
plt.title("GAS PRICES",fontdict={'fontfamily': 'sans-serif','fontsize':19,'fontweight':'bold'})
# plt.plot(gas.Year,gas.USA,'r.-',label='USA')
# plt.plot(gas.Year,gas.Australia,'b.-',label='Australia')
# plt.plot(gas.Year,gas.Canada,'.-',label='Canada')
# plt.plot(gas.Year,gas.Japan,'.-',label='Japan')
# plt.plot(gas.Year,gas['South Korea'],'.-',label='South Korea')
#Another way to plot selected values
coutries_to_look_at = ['Australia','USA','Canada','South Korea','India']
for country in gas:
    if country in coutries_to_look_at:
        plt.plot(gas.Year,gas[country],'.-',label = country)
        
    
print(gas.Year[::3])    
plt.xticks(gas.Year[::3].to_list()+[2011])
plt.xlabel("Years")
plt.ylabel("Prices in USD")
plt.legend()
plt.savefig("Gas_price_Analysis.png",dpi=100)
plt.show()
# Out:
# 0     1990
# 3     1993
# 6     1996
# 9     1999
# 12    2002
# 15    2005
# 18    2008
# Name: Year, dtype: int64
